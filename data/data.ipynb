# %%
import yfinance as yf
import datetime as dt

# Define the symbols to download
symbols = ['AAPL', 'AMZN', 'EURUSD=X', 'GBPUSD=X']
symbols = 'AMZN'

# Define the start and end dates for the data
start_date = '2022-01-11'
end_date = '2023-01-01'

# set current date as end date
# end_date = dt.datetime.now().strftime('%Y-%m-%d')

# Download the data using yfinance
data = yf.download(symbols, start=start_date, end=end_date, interval='5d')

# Extract the desired columns from the data
# data = data.reset_index()[['Date', 'Open', 'High', 'Low', 'Close', 'Volume']]



# Print the head of the data
print(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-11  161.500000  166.350006  160.701508  165.362000  165.362000
# 2022-01-21  149.949997  150.899994  142.070496  142.643005  142.643005
# 2022-01-26  144.750000  145.184998  137.318497  138.872498  138.872498
# 2022-01-31  144.750000  150.360504  144.300507  149.573502  149.573502
# 2022-02-10  158.350006  160.716507  157.750000  159.003494  159.003494
# 2022-02-15  157.605499  158.007004  154.637497  156.510498  156.510498
# 2022-02-25  150.550003  153.990005  149.213501  153.788498  153.788498
# 2022-03-02  150.848999  152.999496  148.750000  152.052505  152.052505
# 2022-03-07  145.443497  146.094498  137.416504  137.453003  137.453003
# 2022-03-17  152.640503  157.498505  152.139999  157.238998  157.238998
# 2022-03-22  161.805496  166.167007  161.699005  164.889008  164.889008
# ...

# %%
import pandas as pd
import pandas_datareader.data as web
import matplotlib.pyplot as plt
from datetime import datetime

start_date = '2022-01-01'
end_date = '2023-01-01'


data = web.DataReader(name="TSLA", data_source='iex', start=start_date, end=end_date)
print(data)

# %%
import pandas_datareader as pdr
pdr.get_data_fred('GS10')
