# %%
import pandas as pd
import numpy as np
import plotnine as p9
import matplotlib.pyplot as plt

date_time = "2023-07-05_20:29"
date_time = "2023-07-10_19:18"
date_time = "2023-07-10_19:51"
date_time = "2023-07-10_21:09"

root_results_dir = "/projects/genomic-ml/da2343/ml_project_2/hpc/results"
df = pd.read_csv(f"{root_results_dir}/{date_time}_results.csv")

# %%
df
# Out:
#     mean_mape  std_mape  train_size dataset_name         algorithm   fh  \
# 0    0.001228  0.001019       67200    EURUSD_H1  LinearRegression  120
# 1    0.001485  0.001209       16800    EURUSD_H1  LinearRegression  120
# 2    0.001375  0.001109       33600    EURUSD_H1  LinearRegression  120
# 3    0.001227  0.001010       67200    EURUSD_H1  LinearRegression  120
# 4    0.001327  0.001081       33600    EURUSD_H1  LinearRegression  120
# 5    0.001516  0.001218       16800    EURUSD_H1  LinearRegression  120
# 6    0.001278  0.001043       67200    EURUSD_H1  LinearRegression  120
# 7    0.001360  0.001095       33600    EURUSD_H1  LinearRegression  120
# 8    0.001267  0.001034       67200    EURUSD_H1  LinearRegression  120
# 9    0.001218  0.001010       67200    EURUSD_H1  LinearRegression  120
# 10   0.001220  0.001012       67200    EURUSD_H1  LinearRegression  120
# 11   0.001362  0.001099       33600    EURUSD_H1  LinearRegression  120
# 12   0.001227  0.001009       67200    EURUSD_H1  LinearRegression  120
# 13   0.001516  0.001220       16800    EURUSD_H1  LinearRegression  120
# 14   0.001471  0.001190       16800    EURUSD_H1  LinearRegression  120
# 15   0.001227  0.001013       67200    EURUSD_H1  LinearRegression  120
# 16   0.001530  0.001236       16800    EURUSD_H1  LinearRegression  120
# 17   0.001516  0.001218       16800    EURUSD_H1  LinearRegression  120
# 18   0.001474  0.001198       16800    EURUSD_H1  LinearRegression  120
# 19   0.001470  0.001195       16800    EURUSD_H1  LinearRegression  120
# 20   0.001470  0.001190       16800    EURUSD_H1  LinearRegression  120
# 21   0.001471  0.001192       16800    EURUSD_H1  LinearRegression  120
# 22   0.001363  0.001096       33600    EURUSD_H1  LinearRegression  120
# 23   0.001266  0.001033       67200    EURUSD_H1  LinearRegression  120
# 24   0.001269  0.001039       67200    EURUSD_H1  LinearRegression  120
# 25   0.001318  0.001072       33600    EURUSD_H1  LinearRegression  120
# 26   0.001473  0.001194       16800    EURUSD_H1  LinearRegression  120
# 27   0.001320  0.001067       33600    EURUSD_H1  LinearRegression  120
# 28   0.001227  0.001013       67200    EURUSD_H1  LinearRegression  120
# 29   0.001317  0.001068       33600    EURUSD_H1  LinearRegression  120
# 30   0.001321  0.001066       33600    EURUSD_H1  LinearRegression  120
# 31   0.001319  0.001068       33600    EURUSD_H1  LinearRegression  120
# 32   0.001319  0.001064       33600    EURUSD_H1  LinearRegression  120
#
#     window_size  sma
# 0           600  200
# 1           600  200
# 2           390  200
# 3           450  200
# 4           600  200
# 5           360  200
# 6           390  200
# 7           330  200
# 8           360  200
# 9           570  200
# 10          540  200
# 11          300  200
# 12          420  200
# 13          300  200
# 14          420  200
# 15          480  200
# 16          390  200
# 17          330  200
# 18          570  200
# 19          540  200
# 20          450  200
# 21          480  200
# 22          360  200
# 23          330  200
# 24          300  200
# 25          570  200
# 26          510  200
# 27          510  200
# 28          510  200
# 29          540  200
# 30          450  200
# 31          480  200
# 32          420  200

# %%
# Import pandas and plotnine
import pandas as pd
from plotnine import *

# filter df only where sma is 200   and fh is 168
# my_df = df[(df["sma"] == 200) & (df["fh"] == 168)]
# my_df = df[(df["window_size"] >= 200) & (df["fh"] == 120)]
my_df = df.copy()

# geom_errorbar(aes(ymin="mean_mape-std_mape", ymax="mean_mape+std_mape")) +
# Draw a line plot with error bars and facet by train_size
p = (ggplot(my_df, aes(x="algorithm", y="mean_mape", color="algorithm")) +
     geom_point(aes(group="dataset_name")) +
     facet_wrap("~train_size + fh + window_size",  labeller=label_both) +
     labs(x="algorithm", y="mean_mape") +
     theme(axis_text_x=element_blank(), axis_title_x=element_blank(), subplots_adjust={'hspace': 0.25}, figure_size=(18, 15)) +
     ggtitle("Mean MAPE by Algorithm and Train Size"))
# save plot
# p.save(f"{root_results_dir}/{date_time}_results.png", dpi=300)
p
# Out:
# <ggplot: (1446649161201)>
