# %%
import sys
import numpy as np
import pandas as pd
import warnings
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import *
from sklearn.mixture import GaussianMixture
from numba import jit
import joblib
import os
import shutil
import json

sys.path.append(
    os.path.abspath(
        "/projects/genomic-ml/da2343/ml_project_2/unsupervised/kmeans"
    )
)
from utils import *

# %%
# Constants
# Define large value for cases with no losses (instead of infinity)
LARGE_VALUE = 1000.0 

# Load trading parameters from CSV
trading_params = pd.read_csv("params.csv")
param_row = 10
param_dict = dict(
    trading_params.iloc[param_row, :]
)  # Assume first row of trading_params.csv

# Extract trading parameters
INSTRUMENT = param_dict["instrument"]
PRICE_HISTORY_LENGTH = int(param_dict["price_history_length"])
# PRICE_HISTORY_LENGTH = 10
NUM_PERCEPTUALLY_IMPORTANT_POINTS = 4
NUM_CLUSTERS = int(param_dict["num_clusters"])
# CLUSTERING_ALGORITHM = param_dict["clustering_algorithm"]
# RANDOM_SEED = int(param_dict["random_seed"])
# TEST_PERIOD = int(param_dict["test_period"])
CLUSTERING_ALGORITHM = "gaussian_mixture"
RANDOM_SEED = 10234
TEST_PERIOD = 2


NUM_CLUSTERS = 5
TRAIN_PERIOD = 4
REVERSE_TEST = False
# REVERSE_TEST = True


# Define clustering algorithms
clustering_estimator_dict = {
    "kmeans": KMeans(n_clusters=NUM_CLUSTERS, 
                     random_state=RANDOM_SEED,
                        n_init=1000),
    "gaussian_mixture": GaussianMixture(
        n_components=NUM_CLUSTERS, 
        covariance_type="tied", 
        random_state=RANDOM_SEED
    ),
    "birch": Birch(n_clusters=NUM_CLUSTERS)
}

# %%
def prepare_test_data(price_subset, instrument_dict, max_trades_per_day=5):
    data_list = []
    scaler = StandardScaler()
    
    # Get instrument's high liquidity hours
    liquidity_start = instrument_dict['market_hours']['high_liquidity_start']
    liquidity_end = instrument_dict['market_hours']['high_liquidity_end']
    
    # Keep track of number of trades per day
    daily_trade_count = {}

    for index in range(PRICE_HISTORY_LENGTH, len(price_subset)):
        # Get price history for PIP calculation
        price_history = (
            price_subset["close"]
            .iloc[max(0, index - PRICE_HISTORY_LENGTH) : index]
            .values
        )
        if len(price_history) < PRICE_HISTORY_LENGTH:
            break

        # Current row index
        j = index - 1
        current_time = price_subset.index[j]
        current_hour = current_time.hour
        current_date = current_time.date()
        
        # Skip if we already took maximum trades for this day
        if daily_trade_count.get(current_date, 0) >= max_trades_per_day:
            continue
        
        # Check if current time is within high liquidity period
        # Handle cases where high liquidity period crosses midnight
        is_liquid_time = False
        if liquidity_start <= liquidity_end:
            is_liquid_time = liquidity_start <= current_hour < liquidity_end
        else:  # Period crosses midnight
            is_liquid_time = current_hour >= liquidity_start or current_hour < liquidity_end
            
        if not is_liquid_time:
            continue
            
        # Find current day's end time (15 mins before actual EOD)
        eod_time = pd.Timestamp.combine(
            current_time.date(), 
            pd.Timestamp('23:45').time()  # 15 mins before midnight
        ).tz_localize('UTC')

        # Get the EOD price (23:45 current day)
        eod_data = price_subset[price_subset.index <= eod_time]
        if len(eod_data) == 0:
            continue
        eod_row = eod_data.iloc[-1]
        
        # Calculate PIPs and scale them
        _, important_points = find_perceptually_important_points(
            price_history, NUM_PERCEPTUALLY_IMPORTANT_POINTS
        )
        scaled_points = scaler.fit_transform(important_points.reshape(-1, 1)).flatten()
        
        # Create data point with scaled PIPs
        data_point = {
            f"price_point_{i}": scaled_points[i]
            for i in range(NUM_PERCEPTUALLY_IMPORTANT_POINTS)
        }

        # Add time features
        data_point.update(
            price_subset.iloc[j][
                ["year", "month", "day_of_week", "hour", "minute"]
            ].to_dict()
        )
        
        # Calculate log return from current point to EOD
        data_point["trade_outcome"] = (eod_row["log_close"] - price_subset["log_close"].iloc[j])
        
        # Increment trade count for this day
        daily_trade_count[current_date] = daily_trade_count.get(current_date, 0) + 1
        
        data_list.append(data_point)

    return pd.DataFrame(data_list)

# %%
# @jit(nopython=True)
def find_perceptually_important_points(price_data, num_points):
    point_indices = np.zeros(num_points, dtype=np.int64)
    point_prices = np.zeros(num_points, dtype=np.float64)
    point_indices[0], point_indices[1] = 0, len(price_data) - 1
    point_prices[0], point_prices[1] = price_data[0], price_data[-1]

    for current_point in range(2, num_points):
        max_distance, max_distance_index, insert_index = 0.0, -1, -1
        for i in range(1, len(price_data) - 1):
            left_adj = (
                np.searchsorted(point_indices[:current_point], i, side="right") - 1
            )
            right_adj = left_adj + 1
            distance = calculate_point_distance(
                price_data,
                point_indices[:current_point],
                point_prices[:current_point],
                i,
                left_adj,
                right_adj,
            )
            if distance > max_distance:
                max_distance, max_distance_index, insert_index = distance, i, right_adj

        point_indices[insert_index + 1 : current_point + 1] = point_indices[
            insert_index:current_point
        ]
        point_prices[insert_index + 1 : current_point + 1] = point_prices[
            insert_index:current_point
        ]
        point_indices[insert_index], point_prices[insert_index] = (
            max_distance_index,
            price_data[max_distance_index],
        )

    return point_indices, point_prices

# @jit(nopython=True)
def calculate_point_distance(
    data, point_indices, point_prices, index, left_adj, right_adj
):
    time_diff = point_indices[right_adj] - point_indices[left_adj]
    price_diff = point_prices[right_adj] - point_prices[left_adj]
    slope = price_diff / time_diff
    x, y = index, data[index]
    return (
        (point_indices[left_adj] - x) ** 2 + (point_prices[left_adj] - y) ** 2
    ) ** 0.5 + (
        (point_indices[right_adj] - x) ** 2 + (point_prices[right_adj] - y) ** 2
    ) ** 0.5


def prepare_data(price_subset, instrument_dict):
    data_list = []
    scaler = StandardScaler()
    
    # Get instrument's high liquidity hours
    liquidity_start = instrument_dict['market_hours']['high_liquidity_start']
    liquidity_end = instrument_dict['market_hours']['high_liquidity_end']

    for index in range(PRICE_HISTORY_LENGTH, len(price_subset)):
        # Get price history for PIP calculation
        price_history = (
            price_subset["close"]
            .iloc[max(0, index - PRICE_HISTORY_LENGTH) : index]
            .values
        )
        if len(price_history) < PRICE_HISTORY_LENGTH:
            break

        # Current row index
        j = index - 1
        current_time = price_subset.index[j]
        current_hour = current_time.hour
        
        # Check if current time is within high liquidity period
        # Handle cases where high liquidity period crosses midnight
        is_liquid_time = False
        if liquidity_start <= liquidity_end:
            is_liquid_time = liquidity_start <= current_hour < liquidity_end
        else:  # Period crosses midnight
            is_liquid_time = current_hour >= liquidity_start or current_hour < liquidity_end
            
        if not is_liquid_time:
            continue
            
        # Find current day's end time (15 mins before actual EOD)
        eod_time = pd.Timestamp.combine(
            current_time.date(), 
            pd.Timestamp('23:45').time()  # 15 mins before midnight
        ).tz_localize('UTC')

        # Get the EOD price (23:45 current day)
        eod_data = price_subset[price_subset.index <= eod_time]
        if len(eod_data) == 0:
            continue
        eod_row = eod_data.iloc[-1]
        
        # Calculate PIPs and scale them
        _, important_points = find_perceptually_important_points(
            price_history, NUM_PERCEPTUALLY_IMPORTANT_POINTS
        )
        scaled_points = scaler.fit_transform(important_points.reshape(-1, 1)).flatten()
        
        # Create data point with scaled PIPs
        data_point = {
            f"price_point_{i}": scaled_points[i]
            for i in range(NUM_PERCEPTUALLY_IMPORTANT_POINTS)
        }

        # Add time features
        data_point.update(
            price_subset.iloc[j][
                ["year", "month", "day_of_week", "hour", "minute"]
            ].to_dict()
        )
        
        # Calculate log return from current point to EOD (next day 00:00)
        data_point["trade_outcome"] = (eod_row["log_close"] -  price_subset["log_close"].iloc[j])
        # print(f"Processing {current_time} to {eod_time}...")
        data_list.append(data_point)

    return pd.DataFrame(data_list)

def evaluate_cluster_performance_df(price_data_df, train_best_cluster, clustering_model):
    # Prepare features for prediction
    price_point_columns = [f"price_point_{i}" for i in range(NUM_PERCEPTUALLY_IMPORTANT_POINTS)]
    feature_columns = price_point_columns + ["day_of_week", "hour", "minute"]
    
    # Predict clusters for test data
    price_features = price_data_df[feature_columns].values
    
    # scale features to 2 decimal places
    price_features = np.round(price_features, 2)
    price_data_df["cluster_label"] = clustering_model.predict(price_features)
    
    # Get the best cluster label and its direction from training
    cluster_label = train_best_cluster['cluster_label']
    trade_direction = train_best_cluster['trade_direction']
    
    # Get trades for the best cluster
    cluster_data = price_data_df[price_data_df['cluster_label'] == cluster_label]
    
    # Get trade outcomes and adjust for direction
    cluster_trades = cluster_data['trade_outcome']
    
    if REVERSE_TEST:
        trade_direction = 'short' if trade_direction == 'long' else 'long'
    
    if trade_direction == 'short':
        cluster_trades = -cluster_trades
    
    # Basic performance metrics
    total_return = cluster_trades.sum()
    num_trades = len(cluster_trades)
    
    # Create performance dictionary
    cluster_performance = {
        "cluster_label": cluster_label,
        "trade_direction": trade_direction,
        "actual_return": total_return,
        "num_trades": num_trades
    }
    return cluster_performance

def cluster_and_evaluate_price_data(price_data_df):
    price_point_columns = [f"price_point_{i}" for i in range(NUM_PERCEPTUALLY_IMPORTANT_POINTS)]
    feature_columns = price_point_columns + ["day_of_week", "hour", "minute"]
    price_features = price_data_df[feature_columns].values
    
    # scale features to 2 decimal places
    price_features = np.round(price_features, 2)
    
    clustering_model = clustering_estimator_dict[CLUSTERING_ALGORITHM]
    clustering_model.fit(price_features)
    price_data_df["cluster_label"] = clustering_model.predict(price_features)

    cluster_metrics = []
    for cluster in price_data_df['cluster_label'].unique():
        cluster_data = price_data_df[price_data_df['cluster_label'] == cluster]
        
        if len(cluster_data) < 5:  # Skip clusters with too few trades
            continue
            
        # Determine if cluster is long or short based on mean return
        cluster_mean = cluster_data['trade_outcome'].mean()
        is_long_cluster = cluster_mean >= 0
        
        # Adjust trade outcomes for short trades
        cluster_trades = cluster_data['trade_outcome']
        if not is_long_cluster:
            cluster_trades = -cluster_trades  # Invert returns for short trades
            
        # Basic metrics
        wins = cluster_trades > 0
        losses = cluster_trades < 0
        
        # 1. Win Rate
        win_rate = np.mean(wins) if len(cluster_trades) > 0 else 0
        
        # 2. Risk-adjusted return
        # Consider dividing by another factor to normalize
        returns_mean = cluster_trades.mean()
        returns_std = cluster_trades.std()
        annualization_factor = np.sqrt(252)
        actual_returns_mean = (np.exp(returns_mean) - 1)
        actual_returns_std = returns_std
        # Add scaling factor for 15-min returns
        scale_factor = 0.5  # This can be adjusted
        sharpe = (actual_returns_mean / actual_returns_std) * annualization_factor * scale_factor if actual_returns_std != 0 else 0
                
        # 3. Maximum Drawdown
        cumulative = cluster_trades.cumsum()
        running_max = cumulative.expanding().max()
        drawdowns = cumulative - running_max
        max_drawdown = abs(drawdowns.min()) if len(drawdowns) > 0 else LARGE_VALUE
        
        # 4. Profit Factor
        gross_profits = cluster_trades[wins].sum() if any(wins) else 0
        gross_losses = abs(cluster_trades[losses].sum()) if any(losses) else 0
        profit_factor = gross_profits / gross_losses if gross_losses != 0 else LARGE_VALUE
        
        # 5. Win/Loss Ratio
        avg_win = cluster_trades[wins].mean() if any(wins) else 0
        avg_loss = abs(cluster_trades[losses].mean()) if any(losses) else LARGE_VALUE
        win_loss_ratio = avg_win / avg_loss if avg_loss != 0 else LARGE_VALUE
        
        # 6. Consistency Score (lower is better)
        returns_volatility = cluster_trades.std()
        
        cluster_metrics.append({
            'cluster_label': cluster,
            'trade_direction': 'long' if is_long_cluster else 'short',
            'num_trades': len(cluster_trades),
            'win_rate': win_rate,
            'sharpe': sharpe,
            'max_drawdown': max_drawdown,
            'profit_factor': profit_factor,
            'win_loss_ratio': win_loss_ratio,
            'returns_volatility': returns_volatility,
            'avg_return': returns_mean,
            'actual_return': cluster_trades.sum(),
            'mean_return': cluster_mean
        })
    metrics_df = pd.DataFrame(cluster_metrics)
    
    print(f"Found {sharpe} sharpe.")
        
#     # Filter for good clusters with realistic performance metrics
#     mask = (
#         (metrics_df['win_rate'].between(0.5, 0.65)) &     # 55-65% win rate
#         (metrics_df['profit_factor'].between(1.5, 2.0)) &  # 1.6-2.0 profit factor
#         (metrics_df['win_loss_ratio'].between(1.2, 2.0)) &  # 1.2-2.0 win/loss ratio
#         (metrics_df['sharpe'].between(0.5, 2.0)) 
#     )
#     # Create an explicit copy of the filtered DataFrame
#     good_clusters = metrics_df[mask].copy()   
#     # Return empty DataFrame if no valid clusters
#     if len(good_clusters) == 0:
#        return {}, clustering_model 
#    # Calculate composite score for filtered clusters
#     good_clusters['consistency_score'] = (
#         good_clusters['win_rate'] / 0.65 * 0.3 +            # Normalized to max 0.65, 30% weight
#         good_clusters['profit_factor'] / 2.0 * 0.2 +        # Normalized to max 2.0, 30% weight
#         good_clusters['win_loss_ratio'] / 2.0 * 0.2 +       # Normalized to max 2.0, 20% weight
#         good_clusters['sharpe'] / 3.0 * 0.2                 # Normalized to max 2.0, 20% weight
#     )
#     print(f"Found {len(good_clusters)} good clusters.")

    mask = (
        # (metrics_df['sharpe'] > 0)          # Win rate above 55%
        (metrics_df['profit_factor'] > 1.5) 
        # (metrics_df['sharpe'] <= 5)             # Sharpe above 0.5
        # (metrics_df['win_loss_ratio'] > 1.2)    # Win/loss ratio above 1.2
    )
    # Create an explicit copy of the filtered DataFrame
    good_clusters = metrics_df[mask].copy()
    # Return empty DataFrame if no valid clusters
    if len(good_clusters) == 0:
        return {}, clustering_model 
    # Calculate composite score for filtered clusters
    good_clusters['consistency_score'] = (
         good_clusters['sharpe']
        # good_clusters['win_rate'] / 0.8 * 0.5 +          # Normalized to max 0.8, 30% weight
        # good_clusters['profit_factor'] / 2.0 * 0.5      # Normalized to max 2.0, 20% weight
        # good_clusters['win_loss_ratio'] / 2.0 * 0.2     # Normalized to max 2.0, 20% weight
        # good_clusters['sharpe'] / 3.0 * 0.3              # Normalized to max 3.0, 30% weight
    )
    print(f"Found {len(good_clusters)} good clusters.")
            
    # Get single best cluster by consistency score
    best_cluster_df = (
        good_clusters
        .sort_values('consistency_score', ascending=False)
        .head(1)
        .reset_index(drop=True)
    )
    best_cluster_dict = best_cluster_df.iloc[0].to_dict()
    return best_cluster_dict, clustering_model


INSTRUMENT = "GBP_JPY_M15"
PROJECT_DIR = "/projects/genomic-ml/da2343/ml_project_2"
# PROJECT_DIR = "/Users/newuser/Projects/robust_algo_trader"
# Load the config file
config_path = f"{PROJECT_DIR}/settings/config_gfd.json"
with open(config_path) as f:
    config = json.load(f)

instrument_dict = config["traded_instruments"][INSTRUMENT.split("_M15")[0]]
time_scaler = joblib.load(f"{PROJECT_DIR}/unsupervised/kmeans/ts_scaler_2018.joblib")
price_data = pd.read_csv(
    f"{PROJECT_DIR}/data/gen_oanda_data/{INSTRUMENT}_raw_data.csv",
    parse_dates=["time"],
    index_col="time",
)

# Filter date range and apply time scaling
price_data = price_data.loc["2019-01-01":"2024-01-01"]
price_data['log_close'] = np.log(price_data['close'])
price_data['log_open'] = np.log(price_data['open'])
price_data["year"] = price_data.index.year
price_data["month"] = price_data.index.month
price_data["day_of_week"] = price_data.index.dayofweek
price_data["hour"] = price_data.index.hour
price_data["minute"] = price_data.index.minute
time_columns = ["day_of_week", "hour", "minute"]
price_data[time_columns] = time_scaler.transform(price_data[time_columns])
# Round price columns
columns_to_round = ['open', 'high', 'low', 'close', 'log_close', "log_open", "day_of_week", "hour", "minute"]
price_data[columns_to_round] = price_data[columns_to_round].round(6)

# Initialize the sliding window splitter for backtesting
window_splitter = OrderedSlidingWindowSplitter(
    train_weeks=TRAIN_PERIOD, test_weeks=TEST_PERIOD, step_size=1
)

backtest_results = []
for window, (train_indices, test_indices) in enumerate(window_splitter.split(price_data), 1):
    
    print(f"Processing window {window}...")
    train_data = price_data.iloc[train_indices, :]
    test_data = price_data.iloc[test_indices, :]

    # Prepare training data and perform clustering
    print("Preparing training data and clustering...")
    train_price_data = prepare_data(train_data, instrument_dict)
    train_cluster_perf, clustering_model = cluster_and_evaluate_price_data(train_price_data)
    if not train_cluster_perf:
        continue

    # Prepare test data and evaluate cluster performance
    test_price_data = prepare_data(test_data, instrument_dict)
    print("Preparing test data and evaluating cluster performance...")
    test_cluster_perf = evaluate_cluster_performance_df(test_price_data, train_cluster_perf, clustering_model)
    
    # check if test_cluster_perf dict is empty
    if not test_cluster_perf:
        continue

    # Compile results for this window
    print("Compiling results...")
    window_result = {
        "window": window,
        # Training metrics (single best cluster)
        "train_actual_return": train_cluster_perf["actual_return"], 
        "train_num_trades": train_cluster_perf["num_trades"], 
        "train_direction": train_cluster_perf["trade_direction"],
        
        # Test metrics (single cluster performance)
        "test_actual_return": test_cluster_perf["actual_return"],
        "test_num_trades": test_cluster_perf["num_trades"], 
        "test_direction": test_cluster_perf["trade_direction"]
    }
    backtest_results.append(window_result)
    # break
    if window >= 200:
        break
# Out:
# Found 3.86549194076268 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 7...
# Preparing training data and clustering...
# Found 3.468944114030416 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 8...
# Preparing training data and clustering...
# Found 3.4203924505258176 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 9...
# Preparing training data and clustering...
# Found 2.354696658536267 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 10...
# Preparing training data and clustering...
# Found 0.16400164459644692 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 11...
# Preparing training data and clustering...
# Found 4.223195488383091 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 12...
# Preparing training data and clustering...
# Found 1.7163904761705346 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 13...
# Preparing training data and clustering...
# Found 5.826579480856821 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 14...
# Preparing training data and clustering...
# Found 0.5919225911165644 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 15...
# Preparing training data and clustering...
# Found 1.4437318395221908 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 16...
# Preparing training data and clustering...
# Found 2.47701032693819 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 17...
# Preparing training data and clustering...
# Found 2.0652936669184956 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 18...
# Preparing training data and clustering...
# Found 2.219314401718931 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 19...
# Preparing training data and clustering...
# Found 1.7478397808465878 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 20...
# Preparing training data and clustering...
# Found 2.6190787615399653 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 21...
# Preparing training data and clustering...
# Found 1.5294172274120865 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 22...
# Preparing training data and clustering...
# Found 0.06373994840230651 sharpe.
# Processing window 23...
# Preparing training data and clustering...
# Found 0.51682290167598 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 24...
# Preparing training data and clustering...
# Found 0.729994110484224 sharpe.
# Found 1 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 25...
# Preparing training data and clustering...
# Found 0.3588458241055767 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 26...
# Preparing training data and clustering...
# Found 0.598157232165847 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 27...
# Preparing training data and clustering...
# Found 4.229003709621727 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 28...
# Preparing training data and clustering...
# Found 4.398227524672997 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 29...
# Preparing training data and clustering...
# Found 1.7262710775664727 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 30...
# Preparing training data and clustering...
# Found 0.054532599410765485 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 31...
# Preparing training data and clustering...
# Found 1.2493465114926792 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 32...
# Preparing training data and clustering...
# Found 2.818429068864606 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 33...
# Preparing training data and clustering...
# Found 2.4608486768092814 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 34...
# Preparing training data and clustering...
# Found 0.6651911544902921 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 35...
# Preparing training data and clustering...
# Found 4.682205852619396 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 36...
# Preparing training data and clustering...
# Found 3.7116366885963132 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 37...
# Preparing training data and clustering...
# Found 2.213973134833003 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 38...
# Preparing training data and clustering...
# Found 1.1273331562359374 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 39...
# Preparing training data and clustering...
# Found 2.5558528308564186 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 40...
# Preparing training data and clustering...
# Found 3.069551166608955 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 41...
# Preparing training data and clustering...
# Found 3.5458127343337686 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 42...
# Preparing training data and clustering...
# Found 1.9304939925949385 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 43...
# Preparing training data and clustering...
# Found 0.9587848055642136 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 44...
# Preparing training data and clustering...
# Found 1.4673592612741173 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 45...
# Preparing training data and clustering...
# Found 1.543390822972076 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 46...
# Preparing training data and clustering...
# Found 1.870684213848175 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 47...
# Preparing training data and clustering...
# Found 0.20956734628707868 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 48...
# Preparing training data and clustering...
# Found 2.7625148502519106 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 49...
# Preparing training data and clustering...
# Found 0.3981397378947274 sharpe.
# Found 1 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 50...
# Preparing training data and clustering...
# Found 0.684841367091111 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 51...
# Preparing training data and clustering...
# Found 1.059345259780602 sharpe.
# Found 1 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 52...
# Preparing training data and clustering...
# Found 0.3598592847021883 sharpe.
# Found 1 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 53...
# Preparing training data and clustering...
# Found 3.827585180689934 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 54...
# Preparing training data and clustering...
# Found 0.8504712299475353 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 55...
# Preparing training data and clustering...
# Found 0.9427228625712062 sharpe.
# Found 1 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 56...
# Preparing training data and clustering...
# Found 1.0736337581268318 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 57...
# Preparing training data and clustering...
# Found 1.177550757029302 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 58...
# Preparing training data and clustering...
# Found 1.7958434208312846 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 59...
# Preparing training data and clustering...
# Found 5.787378655385377 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 60...
# Preparing training data and clustering...
# Found 4.1339314673264544 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 61...
# Preparing training data and clustering...
# Found 0.6481334663797483 sharpe.
# Processing window 62...
# Preparing training data and clustering...
# Found 0.15295681998635574 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 63...
# Preparing training data and clustering...
# Found 0.34086970853057263 sharpe.
# Processing window 64...
# Preparing training data and clustering...
# Found 1.9390872425338352 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 65...
# Preparing training data and clustering...
# Found 3.653168971726938 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 66...
# Preparing training data and clustering...
# Found 0.7456425969666702 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 67...
# Preparing training data and clustering...
# Found 1.3243051801567374 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 68...
# Preparing training data and clustering...
# Found 0.7540041419093139 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 69...
# Preparing training data and clustering...
# Found 0.14731067177991453 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 70...
# Preparing training data and clustering...
# Found 1.3540916724629075 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 71...
# Preparing training data and clustering...
# Found 2.0382328774804135 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 72...
# Preparing training data and clustering...
# Found 2.1162911657459684 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 73...
# Preparing training data and clustering...
# Found 0.3853224819461156 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 74...
# Preparing training data and clustering...
# Found 3.1548438197835393 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 75...
# Preparing training data and clustering...
# Found 0.9062613739181038 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 76...
# Preparing training data and clustering...
# Found 1.4526009445180497 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 77...
# Preparing training data and clustering...
# Found 2.734703887313252 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 78...
# Preparing training data and clustering...
# Found 0.5046302328014503 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 79...
# Preparing training data and clustering...
# Found 1.8459642418893483 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 80...
# Preparing training data and clustering...
# Found 2.299811846871205 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 81...
# Preparing training data and clustering...
# Found 4.384256870488522 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 82...
# Preparing training data and clustering...
# Found 3.404271389165224 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 83...
# Preparing training data and clustering...
# Found 1.184733266919324 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 84...
# Preparing training data and clustering...
# Found 0.02925374867582701 sharpe.
# Found 1 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 85...
# Preparing training data and clustering...
# Found 0.8206339803377826 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 86...
# Preparing training data and clustering...
# Found 1.061846048168323 sharpe.
# Found 1 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 87...
# Preparing training data and clustering...
# Found 0.994073170085769 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 88...
# Preparing training data and clustering...
# Found 2.1003591479967643 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 89...
# Preparing training data and clustering...
# Found 0.347912507172387 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 90...
# Preparing training data and clustering...
# Found 0.0446306089481615 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 91...
# Preparing training data and clustering...
# Found 2.8510035282167743 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 92...
# Preparing training data and clustering...
# Found 1.4446790117273824 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 93...
# Preparing training data and clustering...
# Found 1.1826072233203984 sharpe.
# Found 1 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 94...
# Preparing training data and clustering...
# Found 2.9870945678221945 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 95...
# Preparing training data and clustering...
# Found 3.532796187721156 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 96...
# Preparing training data and clustering...
# Found 4.4340165887009455 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 97...
# Preparing training data and clustering...
# Found 4.942102541665737 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 98...
# Preparing training data and clustering...
# Found 0.7347599774433511 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 99...
# Preparing training data and clustering...
# Found 5.0568111233868045 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 100...
# Preparing training data and clustering...
# Found 4.843292666180285 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 101...
# Preparing training data and clustering...
# Found 1.2401615649132072 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 102...
# Preparing training data and clustering...
# Found 2.521117641064511 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 103...
# Preparing training data and clustering...
# Found 2.017119131962764 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 104...
# Preparing training data and clustering...
# Found 3.7901577037829983 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 105...
# Preparing training data and clustering...
# Found 0.7072900912241821 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 106...
# Preparing training data and clustering...
# Found 1.3880019073812648 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 107...
# Preparing training data and clustering...
# Found 0.9815519445870637 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 108...
# Preparing training data and clustering...
# Found 1.4148882028857357 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 109...
# Preparing training data and clustering...
# Found 4.456565757223637 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 110...
# Preparing training data and clustering...
# Found 1.4730695954675492 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 111...
# Preparing training data and clustering...
# Found 0.8067927070377291 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 112...
# Preparing training data and clustering...
# Found 1.8294382679407835 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 113...
# Preparing training data and clustering...
# Found 0.4006895235045305 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 114...
# Preparing training data and clustering...
# Found 0.17194372357735876 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 115...
# Preparing training data and clustering...
# Found 1.2552469053000401 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 116...
# Preparing training data and clustering...
# Found 0.8422439646747035 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 117...
# Preparing training data and clustering...
# Found 1.1863897718097371 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 118...
# Preparing training data and clustering...
# Found 0.6946798560293755 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 119...
# Preparing training data and clustering...
# Found 2.5918445205782743 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 120...
# Preparing training data and clustering...
# Found 2.5064092692188806 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 121...
# Preparing training data and clustering...
# Found 5.469020326063725 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 122...
# Preparing training data and clustering...
# Found 3.4466127845972907 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 123...
# Preparing training data and clustering...
# Found 1.7874648787625633 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 124...
# Preparing training data and clustering...
# Found 2.1208670789299844 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 125...
# Preparing training data and clustering...
# Found 1.5168400514017317 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 126...
# Preparing training data and clustering...
# Found 0.9392618948791744 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 127...
# Preparing training data and clustering...
# Found 0.25261893323194684 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 128...
# Preparing training data and clustering...
# Found 6.879741879891199 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 129...
# Preparing training data and clustering...
# Found 1.2709546421931261 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 130...
# Preparing training data and clustering...
# Found 1.119191368061072 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 131...
# Preparing training data and clustering...
# Found 6.6233599373685985 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 132...
# Preparing training data and clustering...
# Found 3.4467525833644466 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 133...
# Preparing training data and clustering...
# Found 0.1471365800269708 sharpe.
# Processing window 134...
# Preparing training data and clustering...
# Found 2.982918461336366 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 135...
# Preparing training data and clustering...
# Found 2.5269936097635197 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 136...
# Preparing training data and clustering...
# Found 0.9530988513971493 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 137...
# Preparing training data and clustering...
# Found 0.703350121436014 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 138...
# Preparing training data and clustering...
# Found 0.06026982039937341 sharpe.
# Found 1 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 139...
# Preparing training data and clustering...
# Found 1.9795647901854627 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 140...
# Preparing training data and clustering...
# Found 1.3966868492327844 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 141...
# Preparing training data and clustering...
# Found 0.5559407659089423 sharpe.
# Found 1 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 142...
# Preparing training data and clustering...
# Found 0.9587183392722817 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 143...
# Preparing training data and clustering...
# Found 0.9614068385326187 sharpe.
# Found 1 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 144...
# Preparing training data and clustering...
# Found 1.2343887823230528 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 145...
# Preparing training data and clustering...
# Found 0.8743375437144231 sharpe.
# Processing window 146...
# Preparing training data and clustering...
# Found 0.1686571399611667 sharpe.
# Found 1 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 147...
# Preparing training data and clustering...
# Found 1.0754983080269178 sharpe.
# Processing window 148...
# Preparing training data and clustering...
# Found 0.3719798379642421 sharpe.
# Processing window 149...
# Preparing training data and clustering...
# Found 0.8893540746800591 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 150...
# Preparing training data and clustering...
# Found 0.19345902363860173 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 151...
# Preparing training data and clustering...
# Found 0.19483722365705797 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 152...
# Preparing training data and clustering...
# Found 1.218329264029319 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 153...
# Preparing training data and clustering...
# Found 3.3329593572656955 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 154...
# Preparing training data and clustering...
# Found 3.8906828468635934 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 155...
# Preparing training data and clustering...
# Found 1.8353709519912162 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 156...
# Preparing training data and clustering...
# Found 0.6559425028913994 sharpe.
# Found 1 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 157...
# Preparing training data and clustering...
# Found 1.3924914647016045 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 158...
# Preparing training data and clustering...
# Found 3.538341419541508 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 159...
# Preparing training data and clustering...
# Found 5.7250573912724505 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 160...
# Preparing training data and clustering...
# Found 1.3001944884733003 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 161...
# Preparing training data and clustering...
# Found 1.297175597587142 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 162...
# Preparing training data and clustering...
# Found 1.4830044881022975 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 163...
# Preparing training data and clustering...
# Found 0.8643284037306627 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 164...
# Preparing training data and clustering...
# Found 1.221686261004649 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 165...
# Preparing training data and clustering...
# Found 3.511424273044186 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 166...
# Preparing training data and clustering...
# Found 3.647153417477478 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 167...
# Preparing training data and clustering...
# Found 7.154304052417463 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 168...
# Preparing training data and clustering...
# Found 3.1551046909097415 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 169...
# Preparing training data and clustering...
# Found 4.004064797827507 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 170...
# Preparing training data and clustering...
# Found 2.3055570218178825 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 171...
# Preparing training data and clustering...
# Found 3.041153274907645 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 172...
# Preparing training data and clustering...
# Found 0.7262036856439377 sharpe.
# Found 1 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 173...
# Preparing training data and clustering...
# Found 1.9509737590921201 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 174...
# Preparing training data and clustering...
# Found 4.362637836171139 sharpe.
# Found 1 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 175...
# Preparing training data and clustering...
# Found 0.767354288445784 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 176...
# Preparing training data and clustering...
# Found 1.393485823930592 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 177...
# Preparing training data and clustering...
# Found 2.058340849487097 sharpe.
# Found 5 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 178...
# Preparing training data and clustering...
# Found 4.073892794909238 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 179...
# Preparing training data and clustering...
# Found 0.0011593996344747988 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 180...
# Preparing training data and clustering...
# Found 2.8237134576482172 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 181...
# Preparing training data and clustering...
# Found 1.0904735729018034 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 182...
# Preparing training data and clustering...
# Found 1.058173092657859 sharpe.
# Processing window 183...
# Preparing training data and clustering...
# Found 0.6150797257857469 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 184...
# Preparing training data and clustering...
# Found 1.3159246520012757 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 185...
# Preparing training data and clustering...
# Found 0.11711765440775392 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 186...
# Preparing training data and clustering...
# Found 0.350921426856789 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 187...
# Preparing training data and clustering...
# Found 1.7055462634356513 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 188...
# Preparing training data and clustering...
# Found 2.44976655864438 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 189...
# Preparing training data and clustering...
# Found 0.6902682558589265 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 190...
# Preparing training data and clustering...
# Found 0.28288656184468386 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 191...
# Preparing training data and clustering...
# Found 2.631031570659056 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 192...
# Preparing training data and clustering...
# Found 2.149699071133769 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 193...
# Preparing training data and clustering...
# Found 4.1336585959690515 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 194...
# Preparing training data and clustering...
# Found 0.8710481316861192 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 195...
# Preparing training data and clustering...
# Found 1.489498070569223 sharpe.
# Found 4 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 196...
# Preparing training data and clustering...
# Found 0.8040355370444462 sharpe.
# Found 1 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 197...
# Preparing training data and clustering...
# Found 0.1286448037906336 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 198...
# Preparing training data and clustering...
# Found 0.9336984157448543 sharpe.
# Found 3 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 199...
# Preparing training data and clustering...
# Found 0.9656280672117717 sharpe.
# Found 1 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...
# Processing window 200...
# Preparing training data and clustering...
# Found 2.2320530670602694 sharpe.
# Found 2 good clusters.
# Preparing test data and evaluating cluster performance...
# Compiling results...

# %%
# Create base DataFrame from backtest results
backtest_results_df = pd.DataFrame(backtest_results)

# Get returns series
# Calculate metrics for train returns
train_returns = backtest_results_df['train_actual_return']
train_sharpe = (
    np.mean(train_returns) / np.std(train_returns)
    if np.std(train_returns) != 0 else LARGE_VALUE
)
train_winning_trades = train_returns[train_returns > 0]
train_losing_trades = train_returns[train_returns < 0]
train_gross_profits = train_winning_trades.sum() if len(train_winning_trades) > 0 else 0
train_gross_losses = abs(train_losing_trades.sum()) if len(train_losing_trades) > 0 else 0
train_profit_factor = train_gross_profits / train_gross_losses if train_gross_losses != 0 else LARGE_VALUE

# Calculate metrics for test returns
test_returns = backtest_results_df['test_actual_return']
test_sharpe = (
    np.mean(test_returns) / np.std(test_returns)
    if np.std(test_returns) != 0 else LARGE_VALUE
)
test_winning_trades = test_returns[test_returns > 0]
test_losing_trades = test_returns[test_returns < 0]
test_gross_profits = test_winning_trades.sum() if len(test_winning_trades) > 0 else 0
test_gross_losses = abs(test_losing_trades.sum()) if len(test_losing_trades) > 0 else 0
test_profit_factor = test_gross_profits / test_gross_losses if test_gross_losses != 0 else LARGE_VALUE

# Train Performance metrics
backtest_results_df['train_actual_return'] = round(backtest_results_df['train_actual_return'], 6)
backtest_results_df["train_average_return"] = round(train_returns.mean(), 6)
backtest_results_df["train_sharpe_ratio"] = round(train_sharpe, 6)
backtest_results_df["train_profit_factor"] = round(train_profit_factor, 6)
backtest_results_df["train_total_trades"] = backtest_results_df['train_num_trades'].sum()
backtest_results_df["train_avg_trades_per_window"] = round(backtest_results_df['train_num_trades'].mean(), 6)
backtest_results_df["train_win_ratio"] = round((train_returns > 0).mean() + (train_returns == 0).mean()/2, 6)

# Test Performance metrics
backtest_results_df['test_actual_return'] = round(backtest_results_df['test_actual_return'], 6)
backtest_results_df["test_average_return"] = round(test_returns.mean(), 6)
backtest_results_df["test_sharpe_ratio"] = round(test_sharpe, 6)
backtest_results_df["test_profit_factor"] = round(test_profit_factor, 6)
backtest_results_df["test_total_trades"] = backtest_results_df['test_num_trades'].sum()
backtest_results_df["test_avg_trades_per_window"] = round(backtest_results_df['test_num_trades'].mean(), 6)
backtest_results_df["test_win_ratio"] = round((test_returns > 0).mean() + (test_returns == 0).mean()/2, 6)

# General statistics
backtest_results_df["total_windows"] = len(backtest_results_df)
# Configuration parameters (no rounding needed for these)
backtest_results_df["reverse_test"] = REVERSE_TEST
backtest_results_df["num_clusters"] = NUM_CLUSTERS
backtest_results_df["clustering_algorithm"] = CLUSTERING_ALGORITHM
backtest_results_df["train_period"] = TRAIN_PERIOD
backtest_results_df["test_period"] = TEST_PERIOD
backtest_results_df["random_seed"] = RANDOM_SEED
backtest_results_df["instrument"] = INSTRUMENT
backtest_results_df["num_pips"] = NUM_PERCEPTUALLY_IMPORTANT_POINTS

backtest_results_df
# Out:
#      window  train_actual_return  train_num_trades train_direction  \
# 0         1             0.212951                67            long
# 1         2             0.155989                52            long
# 2         3             0.158086               103            long
# 3         4             0.102078               106           short
# 4         5             0.339392               229            long
# ..      ...                  ...               ...             ...
# 187     196             0.198721               164            long
# 188     197             0.245054               162            long
# 189     198             0.182403                83            long
# 190     199             0.179042               137           short
# 191     200             0.080386                75           short
#
#      test_actual_return  test_num_trades test_direction  train_average_return  \
# 0              0.009418               21           long              0.180157
# 1             -0.000333               19           long              0.180157
# 2              0.035749               30           long              0.180157
# 3             -0.082767               45          short              0.180157
# 4              0.521719               95           long              0.180157
# ..                  ...              ...            ...                   ...
# 187            0.052633               43           long              0.180157
# 188           -0.089322               73           long              0.180157
# 189           -0.041662               49           long              0.180157
# 190           -0.050045               39          short              0.180157
# 191            0.089677               53          short              0.180157
#
#      train_sharpe_ratio  train_profit_factor  ...  test_win_ratio  \
# 0               1.40241               1000.0  ...        0.515625
# 1               1.40241               1000.0  ...        0.515625
# 2               1.40241               1000.0  ...        0.515625
# 3               1.40241               1000.0  ...        0.515625
# 4               1.40241               1000.0  ...        0.515625
# ..                  ...                  ...  ...             ...
# 187             1.40241               1000.0  ...        0.515625
# 188             1.40241               1000.0  ...        0.515625
# 189             1.40241               1000.0  ...        0.515625
# 190             1.40241               1000.0  ...        0.515625
# 191             1.40241               1000.0  ...        0.515625
#
#      total_windows  reverse_test  num_clusters  clustering_algorithm  \
# 0              192         False             5      gaussian_mixture
# 1              192         False             5      gaussian_mixture
# 2              192         False             5      gaussian_mixture
# 3              192         False             5      gaussian_mixture
# 4              192         False             5      gaussian_mixture
# ..             ...           ...           ...                   ...
# 187            192         False             5      gaussian_mixture
# 188            192         False             5      gaussian_mixture
# 189            192         False             5      gaussian_mixture
# 190            192         False             5      gaussian_mixture
# 191            192         False             5      gaussian_mixture
#
#      train_period  test_period  random_seed   instrument  num_pips
# 0               4            2        10234  GBP_JPY_M15         4
# 1               4            2        10234  GBP_JPY_M15         4
# 2               4            2        10234  GBP_JPY_M15         4
# 3               4            2        10234  GBP_JPY_M15         4
# 4               4            2        10234  GBP_JPY_M15         4
# ..            ...          ...          ...          ...       ...
# 187             4            2        10234  GBP_JPY_M15         4
# 188             4            2        10234  GBP_JPY_M15         4
# 189             4            2        10234  GBP_JPY_M15         4
# 190             4            2        10234  GBP_JPY_M15         4
# 191             4            2        10234  GBP_JPY_M15         4
#
# [192 rows x 28 columns]

# %%
# plot the test_actual_return column from the backtest_results_df DataFrame
# make a cumulative sum of the test_actual_return column
# plot the cumulative sum


import matplotlib.pyplot as plt
import seaborn as sns

# Set up the matplotlib figure
plt.figure(figsize=(12, 6))
plt.title("Cumulative Returns")
plt.xlabel("Window")
plt.ylabel("Cumulative Return")
plt.plot(backtest_results_df["test_actual_return"].cumsum())
plt.show()

# %%
# save results to csv
out_file = f"results/{param_row}.csv"
results_df.to_csv(out_file, encoding="utf-8", index=False)
print("Backtesting completed.")
