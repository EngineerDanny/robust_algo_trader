# %%
# Import the libraries
import pandas as pd
import matplotlib.pyplot as plt

# Read the data from the CSV file
# data = pd.read_csv("/projects/genomic-ml/da2343/ml_project_2/cnn/results/2023-12-23_13:34_results.csv")
df = pd.read_csv("/Users/newuser/Projects/robust-algo-trader/cnn/results/2023-12-23_13:34_results.csv")
# Group the data by the dataset_name column
# groups = data.groupby("dataset_name")

# %%
df
# Out:
#      Year  Return  trades  Max Drawdown  Percent Return dataset_name  \
# 0    2007      -2      14             3      -14.285714    EURGBP_H1
# 1    2008      -9      60            12      -15.000000    EURGBP_H1
# 2    2009      23      61             7       37.704918    EURGBP_H1
# 3    2010       4      65            11        6.153846    EURGBP_H1
# 4    2011       3      60             8        5.000000    EURGBP_H1
# ..    ...     ...     ...           ...             ...          ...
# 675  2019      -4      34             6      -11.764706    AUDUSD_H1
# 676  2020      -4      52             7       -7.692308    AUDUSD_H1
# 677  2021      13      44             7       29.545455    AUDUSD_H1
# 678  2022      18      66            10       27.272727    AUDUSD_H1
# 679  2023       3      30            16       10.000000    AUDUSD_H1
#
#      threshold
# 0          0.5
# 1          0.5
# 2          0.5
# 3          0.5
# 4          0.5
# ..         ...
# 675        0.8
# 676        0.8
# 677        0.8
# 678        0.8
# 679        0.8
#
# [680 rows x 7 columns]

# %%
import plotnine as p9

sub_df = df[df['threshold'] == 0.9]
# sub_df = df[df['dataset_name'] == 'USDCHF_H1']
# sub_df = df[df['dataset_name'] == 'GBPUSD_H1']
# sub_df = df[df['dataset_name'] == 'AUDCAD_H1']
# sub_df = df[df['dataset_name'] == 'EURJPY_H1']
# sub_df = df[df['dataset_name'] == 'USDJPY_H1']
# sub_df = df[df['dataset_name'] == 'AUDUSD_H1']
# sub_df = df[df['dataset_name'] == 'AUDCHF_H1']
# sub_df = df[df['dataset_name'] == 'EURUSD_H1']
# sub_df = df[df['dataset_name'] == 'USDCAD_H1']
gg = p9.ggplot() +\
    p9.facet_grid(". ~ dataset_name+threshold", labeller='label_both') +\
    p9.geom_bar(data=sub_df, 
                mapping=p9.aes(x='Year', y='Return'), stat="identity")

gg.save(f"loss_df.png", width=20, height=7, dpi=500)
gg
# Out:
# /Users/newuser/opt/miniconda3/envs/cs499f22/lib/python3.9/site-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 20 x 7 in image.
# /Users/newuser/opt/miniconda3/envs/cs499f22/lib/python3.9/site-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: loss_df.png
# <Figure Size: (640 x 480)>

# %%
import plotnine as p9

sub_df = df[df['dataset_name'] == 'EURGBP_H1']
sub_df = df[df['dataset_name'] == 'USDCHF_H1']
sub_df = df[df['dataset_name'] == 'GBPUSD_H1']
sub_df = df[df['dataset_name'] == 'AUDCAD_H1']
sub_df = df[df['dataset_name'] == 'EURJPY_H1']
sub_df = df[df['dataset_name'] == 'USDJPY_H1']
sub_df = df[df['dataset_name'] == 'AUDUSD_H1']
sub_df = df[df['dataset_name'] == 'AUDCHF_H1']
sub_df = df[df['dataset_name'] == 'EURUSD_H1']
sub_df = df[df['dataset_name'] == 'USDCAD_H1']
gg = p9.ggplot() +\
    p9.facet_grid(". ~ dataset_name+threshold", labeller='label_both') +\
    p9.geom_bar(data=sub_df, 
                mapping=p9.aes(x='Year', y='trades'), stat="identity")

# gg.save(f"loss_df.png", width=20, height=7, dpi=500)
gg
# Out:
# <Figure Size: (640 x 480)>
